# %%
import Pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import Pandas as pd
#
# ModuleNotFoundError: No module named 'Pandas'

# %%
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'numpy'

# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 262.6 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 327.7 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 295.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.5 MB 328.2 kB/s eta 0:00:48
#    ---------------------------------------- 0.1/15.5 MB 374.1 kB/s eta 0:00:42
#    ---------------------------------------- 0.1/15.5 MB 425.1 kB/s eta 0:00:37
# ...

# %%
import numpy as np

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 4.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/11.5 MB 5.0 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/11.5 MB 3.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/11.5 MB 4.2 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.5 MB 3.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.5 MB 4.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.5 MB 4.7 MB/s eta 0:00:03
#    ------ --------------------------------- 2.0/11.5 MB 4.9 MB/s eta 0:00:02
#    ------- -------------------------------- 2.2/11.5 MB 4.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.5 MB 4.8 MB/s eta 0:00:02
#    --------- ------------------------------ 2.7/11.5 MB 4.8 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
file_path = E:\SRM\SEM 3\INTERSHIP
# Out:
#   Cell In[9], line 1
#     file_path = E:\SRM\SEM 3\INTERSHIP
#                  ^
# SyntaxError: invalid syntax

# %%
file_name = 'train.csv'

# %%
file_path = r'E:\SRM\SEM 3\INTERSHIP\train.csv'

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
data.shape
# Out:
# (9800, 18)

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
column_name = "State"

# %%
"State"
# Out:
# 'State'

# %%
column_name
# Out:
# 'State'

# %%
column_data = data[column_name]

# %%
print()

# %%
print(column_data )
# Out:
# 0         Kentucky
# 1         Kentucky
# 2       California
# 3          Florida
# 4          Florida
#            ...
# 9795      Illinois
# 9796          Ohio
# 9797          Ohio
# 9798          Ohio
# 9799          Ohio
# Name: State, Length: 9800, dtype: object

# %%
data = data.loc[data["State"] == "California"]
data = data.loc[data["Ship Mode"] != "Second Class"]

# %%
data.shape
# Out:
# (1560, 18)

# %%
data = data[(data["Ship Date"].dt.year==2016)]

# %%
# Out:
# C:\Users\Narahari S\AppData\Local\Temp\ipykernel_10996\3688868455.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
data = data[(data["Ship Date"].dt.year==2016)]

# %%
print(data)
# Out:
#       Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 62        63  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 63        64  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 64        65  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 65        66  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 145      146  CA-2016-110744  07/09/2016 2016-09-12  Standard Class
# ...      ...             ...         ...        ...             ...
# 9574    9575  CA-2016-148495  13/08/2016 2016-08-13        Same Day
# 9598    9599  CA-2016-149517  19/09/2016 2016-09-23  Standard Class
# 9664    9665  US-2016-120957  07/12/2016 2016-12-07        Same Day
# 9679    9680  CA-2016-130113  27/12/2016 2016-12-31  Standard Class
# 9680    9681  CA-2016-130113  27/12/2016 2016-12-31  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
column_data = data[column_name]

# %%
print(column_data)
# Out:
# 62      California
# 63      California
# 64      California
# 65      California
# 145     California
#            ...
# 9574    California
# 9598    California
# 9664    California
# 9679    California
# 9680    California
# Name: State, Length: 313, dtype: object

# %%
data.shape
# Out:
# (313, 18)

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.8 kB ? eta -:--:--
#      ---------------------------- --------- 122.9/162.8 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.7 MB 7.7 MB/s eta 0:00:01
#    - -------------------------------------- 0.4/7.7 MB 7.4 MB/s eta 0:00:01
#    - -------------------------------------- 0.4/7.7 MB 7.4 MB/s eta 0:00:01
#    - -------------------------------------- 0.4/7.7 MB 7.4 MB/s eta 0:00:01
#    - -------------------------------------- 0.4/7.7 MB 7.4 MB/s eta 0:00:01
#    - -------------------------------------- 0.4/7.7 MB 7.4 MB/s eta 0:00:01
#    - -------------------------------------- 0.4/7.7 MB 7.4 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.head
# Out:
# <bound method NDFrame.head of       Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 62        63  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 63        64  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 64        65  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 65        66  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 145      146  CA-2016-110744  07/09/2016 2016-09-12  Standard Class
# ...      ...             ...         ...        ...             ...
# 9574    9575  CA-2016-148495  13/08/2016 2016-08-13        Same Day
# 9598    9599  CA-2016-149517  19/09/2016 2016-09-23  Standard Class
# 9664    9665  US-2016-120957  07/12/2016 2016-12-07        Same Day
# 9679    9680  CA-2016-130113  27/12/2016 2016-12-31  Standard Class
# 9680    9681  CA-2016-130113  27/12/2016 2016-12-31  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
data.head()
# Out:
#      Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 62       63  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 63       64  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 64       65  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 65       66  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 145     146  CA-2016-110744  07/09/2016 2016-09-12  Standard Class
#
#     Customer ID   Customer Name   Segment        Country         City  \
# 62     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 63     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 64     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 65     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 145    HA-14920  Helen Andreada  Consumer  United States     Pasadena
#
#           State  Postal Code Region       Product ID         Category  \
# ...

# %%
data['month'] = data['Ship Date'].apply(lambda x: x.strftime("%Y-%m-%d")[:7])

# %%
print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 print(month)
#
# NameError: name 'month' is not defined

# %%
data['month'] = data['Ship Date'].apply(lambda x: x.strftime("%Y-%m-%d")[:7])

# %%
data.head()
# Out:
#      Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 62       63  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 63       64  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 64       65  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 65       66  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 145     146  CA-2016-110744  07/09/2016 2016-09-12  Standard Class
#
#     Customer ID   Customer Name   Segment        Country         City  \
# 62     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 63     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 64     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 65     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 145    HA-14920  Helen Andreada  Consumer  United States     Pasadena
#
#           State  Postal Code Region       Product ID         Category  \
# ...

# %%
monthly_sales_value = data["month"].value_counts()

# %%
type(monthly_sales_value)
# Out:
# pandas.core.series.Series

# %%
monthly_sales_value.sort_index(inplace=True)

# %%
monthly_sales_value
# Out:
# month
# 2016-01    17
# 2016-02    10
# 2016-03    17
# 2016-04    19
# 2016-05    29
# 2016-06    14
# 2016-07    15
# 2016-08    22
# 2016-09    43
# 2016-10    37
# 2016-11    44
# 2016-12    46
# Name: count, dtype: int64

# %%
monthly_sales_value = sorted(monthly_sales_value)

# %%
monthly_sales_value
# Out:
# [10, 14, 15, 17, 17, 19, 22, 29, 37, 43, 44, 46]

# %%
monthly_sales_value.sort_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 monthly_sales_value.sort_index(inplace=True)
#
# AttributeError: 'list' object has no attribute 'sort_index'

# %%
type(monthly_sales_value)
# Out:
# list

# %%
monthly_sales_value = data["month"].value_counts()

# %%
type(monthly_sales_value)
# Out:
# pandas.core.series.Series

# %%
monthly_sales_value.sort_index(inplace=True)

# %%
monthly_sales_value
# Out:
# month
# 2016-01    17
# 2016-02    10
# 2016-03    17
# 2016-04    19
# 2016-05    29
# 2016-06    14
# 2016-07    15
# 2016-08    22
# 2016-09    43
# 2016-10    37
# 2016-11    44
# 2016-12    46
# Name: count, dtype: int64

# %%
plt.plot(monthly_sales_value)
plt.title('Monthly Sales in the year 2018')
plt.ylabel('total number of sales')
plt.xlabel('month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(monthly_sales_value)
#       2 plt.title('Monthly Sales in the year 2018')
#       3 plt.ylabel('total number of sales')
#
# NameError: name 'plt' is not defined

# %%
plt.title('Monthly Sales in the year 2018')
plt.ylabel('total number of sales')
plt.xlabel('march')
# Out:
# Text(0.5, 0, 'march')

# %%
plt.plot(monthly_sales_value)
plt.title('Monthly Sales in the year 2018')
plt.ylabel('total number of sales')
plt.xlabel('month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.plot(monthly_sales_value)
#       2 plt.title('Monthly Sales in the year 2018')
#       3 plt.ylabel('total number of sales')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib as plt

# %%
plt.plot(monthly_sales_value)
plt.title('Monthly Sales in the year 2018')
plt.ylabel('total number of sales')
plt.xlabel('month')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.plot(monthly_sales_value)
#       2 plt.title('Monthly Sales in the year 2018')
#       3 plt.ylabel('total number of sales')
#
# File ~\anaconda3\envs\examples\Lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
# doing above coding 2nd time

# %%
import numpy as np
import pandas as pd

# %%
file_name = 'train.csv'

# %%
file_path = r'E:\SRM\SEM 3\INTERSHIP\train.csv'

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
data.shape
# Out:
# (9800, 18)

# %%
data = data.loc[data["State"] == "California"]
data = data.loc[data["Ship Mode"] != "Second Class"]

# %%
data = data[(data["Ship Date"].dt.year==2016)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data = data[(data["Ship Date"].dt.year==2016)]
#
# File ~\anaconda3\envs\examples\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\envs\examples\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
data = data[(data["Ship Date"].dt.year==2016)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data = data[(data["Ship Date"].dt.year==2016)]
#
# File ~\anaconda3\envs\examples\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\envs\examples\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
data = data[(data["Ship Date"].dt.year==2016)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 data = data[(data["Ship Date"].dt.year==2016)]
#
# File ~\anaconda3\envs\examples\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\envs\examples\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
# Out:
# C:\Users\Narahari S\AppData\Local\Temp\ipykernel_440\3688868455.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
data = data[data['Ship Date'].dt.year == 2016]

# %%
data
# Out:
#       Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 62        63  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 63        64  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 64        65  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 65        66  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 145      146  CA-2016-110744  07/09/2016 2016-09-12  Standard Class
# ...      ...             ...         ...        ...             ...
# 9574    9575  CA-2016-148495  13/08/2016 2016-08-13        Same Day
# 9598    9599  CA-2016-149517  19/09/2016 2016-09-23  Standard Class
# 9664    9665  US-2016-120957  07/12/2016 2016-12-07        Same Day
# 9679    9680  CA-2016-130113  27/12/2016 2016-12-31  Standard Class
# 9680    9681  CA-2016-130113  27/12/2016 2016-12-31  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
data.shape
# Out:
# (313, 18)

# %%
import matplotlib.pyplot as plt

# %%
data['month'] = data['Ship Date'].apply(lambda x: x.strftime("%Y-%m-%d")[:7])

# %%
data
# Out:
#       Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 62        63  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 63        64  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 64        65  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 65        66  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 145      146  CA-2016-110744  07/09/2016 2016-09-12  Standard Class
# ...      ...             ...         ...        ...             ...
# 9574    9575  CA-2016-148495  13/08/2016 2016-08-13        Same Day
# 9598    9599  CA-2016-149517  19/09/2016 2016-09-23  Standard Class
# 9664    9665  US-2016-120957  07/12/2016 2016-12-07        Same Day
# 9679    9680  CA-2016-130113  27/12/2016 2016-12-31  Standard Class
# 9680    9681  CA-2016-130113  27/12/2016 2016-12-31  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
monthly_sales_value = data["month"].value_counts()

# %%
type(monthly_sales_value)
# Out:
# pandas.core.series.Series

# %%
monthly_sales_value.sort_index(inplace=True)

# %%
monthly_sales_value
# Out:
# month
# 2016-01    17
# 2016-02    10
# 2016-03    17
# 2016-04    19
# 2016-05    29
# 2016-06    14
# 2016-07    15
# 2016-08    22
# 2016-09    43
# 2016-10    37
# 2016-11    44
# 2016-12    46
# Name: count, dtype: int64

# %%
monthly_sales_value
# Out:
# month
# 2016-01    17
# 2016-02    10
# 2016-03    17
# 2016-04    19
# 2016-05    29
# 2016-06    14
# 2016-07    15
# 2016-08    22
# 2016-09    43
# 2016-10    37
# 2016-11    44
# 2016-12    46
# Name: count, dtype: int64

# %%
plt.plot(monthly_sales_value)
plt.title('Monthly Sales in the year 2018')
plt.ylabel('total number of sales')
plt.xlabel('month')
# Out:
# Text(0.5, 0, 'month')

# %%
plt.rcParams['font.size'] = 12

# %%
rParams

# %%
plt.plot(monthly_sales_value)
plt.title('Monthly Sales in the year 2018')
plt.ylabel('total number of sales')
plt.xlabel('month')
# Out:
# Text(0.5, 0, 'month')

# %%
plt.rcParams['font.size'] = 8

# %%
plt.plot(monthly_sales_value)
plt.title('Monthly Sales in the year 2018')
plt.ylabel('total number of sales')
plt.xlabel('month')
# Out:
# Text(0.5, 0, 'month')

# %%
plt.rcParams['font.size'] = 4

# %%
plt.plot(monthly_sales_value)
plt.title('Monthly Sales in the year 2018')
plt.ylabel('total number of sales')
plt.xlabel('month')
# Out:
# Text(0.5, 0, 'month')

# %%
plt.rcParams['font.size'] = 6

# %%
plt.plot(monthly_sales_value)
plt.title('Monthly Sales in the year 2018')
plt.ylabel('total number of sales')
plt.xlabel('month')
# Out:
# Text(0.5, 0, 'month')

# %%
#second objective : Observe the daily sales vlome in the month of july 2018

# %%
data = data[data["Ship date"].dt.month == 7]

daily_Sales_vlo = data["Ship date"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\examples\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ship date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 data = data[data["Ship date"].dt.month == 7]
# ...

# %%
data = data[data["Ship date"].dt.month == 7]

daily_Sales_vlo = data["Ship date"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\examples\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ship date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 data = data[data["Ship date"].dt.month == 7]
# ...

# %%
data.head()
# Out:
#      Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 62       63  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 63       64  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 64       65  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 65       66  CA-2016-135545  24/11/2016 2016-11-30  Standard Class
# 145     146  CA-2016-110744  07/09/2016 2016-09-12  Standard Class
#
#     Customer ID   Customer Name   Segment        Country         City  \
# 62     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 63     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 64     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 65     KM-16720    Kunst Miller  Consumer  United States  Los Angeles
# 145    HA-14920  Helen Andreada  Consumer  United States     Pasadena
#
#           State  Postal Code Region       Product ID         Category  \
# ...

# %%
data = data[data["Ship Date"].dt.month == 7]

daily_Sales_vlo = data["Ship Date"].value_counts()

# %%
daily_Sales_vlo
# Out:
# Ship Date
# 2016-07-31    6
# 2016-07-01    3
# 2016-07-16    2
# 2016-07-11    1
# 2016-07-22    1
# 2016-07-30    1
# 2016-07-14    1
# Name: count, dtype: int64

# %%
plt.plot(daily_Sales_vlo)
plt.title('Sale of the month 2018')
plt.ylabel('total number of sales')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
 = daily_Sales_vlo.sort_values()sorted_daily_sales_vlo

# %%
plt.plot(sorted_daily_sales_vlo)
plt.title('Sale of the month 2018')
plt.ylabel('total number of sales')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
sorted_daily_sales_vlo
# Out:
# Ship Date
# 2016-07-11    1
# 2016-07-22    1
# 2016-07-30    1
# 2016-07-14    1
# 2016-07-16    2
# 2016-07-01    3
# 2016-07-31    6
# Name: count, dtype: int64

# %%
sorted_daily_sales_vlo = daily_Sales_vlo.sort_values()

# %%
sorted_daily_sales_vlo
# Out:
# Ship Date
# 2016-07-11    1
# 2016-07-22    1
# 2016-07-30    1
# 2016-07-14    1
# 2016-07-16    2
# 2016-07-01    3
# 2016-07-31    6
# Name: count, dtype: int64

# %%
plt.plot(sorted_daily_sales_vlo)
plt.title('Sale of the month 2018')
plt.ylabel('total number of sales')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
data
# Out:
#       Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 271      272  CA-2016-155334  30/07/2016 2016-07-31     First Class
# 272      273  CA-2016-155334  30/07/2016 2016-07-31     First Class
# 273      274  CA-2016-155334  30/07/2016 2016-07-31     First Class
# 2539    2540  CA-2016-113404  16/07/2016 2016-07-16        Same Day
# 2540    2541  CA-2016-113404  16/07/2016 2016-07-16        Same Day
# 4314    4315  CA-2016-115945  25/06/2016 2016-07-01  Standard Class
# 4315    4316  CA-2016-115945  25/06/2016 2016-07-01  Standard Class
# 4316    4317  CA-2016-115945  25/06/2016 2016-07-01  Standard Class
# 5163    5164  CA-2016-161627  06/07/2016 2016-07-11  Standard Class
# 5831    5832  CA-2016-111206  18/07/2016 2016-07-22  Standard Class
# 6943    6944  CA-2016-139248  25/07/2016 2016-07-30  Standard Class
# 7434    7435  CA-2016-148180  26/07/2016 2016-07-31  Standard Class
# 7435    7436  CA-2016-148180  26/07/2016 2016-07-31  Standard Class
# ...

# %%
daily_price = data.groupby(['Ship Date','Category'])['Ship Date'].count().unstack()

# %%
daily_price
# Out:
# Category    Furniture  Office Supplies  Technology
# Ship Date
# 2016-07-01        NaN              3.0         NaN
# 2016-07-11        1.0              NaN         NaN
# 2016-07-14        NaN              1.0         NaN
# 2016-07-16        2.0              NaN         NaN
# 2016-07-22        NaN              NaN         1.0
# 2016-07-30        NaN              NaN         1.0
# 2016-07-31        1.0              4.0         1.0

# %%
daily_price.plot()

plt.title('Average daily sales of different property types in the month of July 2018')
plt.ylabel('Number os sales')
plt.xlabel('Date')
plt.ylim(0,5)

#plt.rcParams['figure.figsize'] = (10,5)
# Out:
# (0.0, 5.0)

# %%
plt.ylim(0,5)
# Out:
# (0.0, 5.0)

# %%
daily_price.plot()

plt.title('Average daily sales of different property types in the month of July 2018')
plt.ylabel('Number os sales')
plt.xlabel('Date')
plt.ylim(0,5)
# Out:
# (0.0, 5.0)

# %%
# For bar chart use arguement kind = 'barh'

# %%
daily_price.plot()

plt.title('Average daily sales of different property types in the month of July 2018')
plt.ylabel('Number os sales')
plt.xlabel('Date')
plt.ylim(0,5)
# Out:
# (0.0, 5.0)

# %%
#objective draw comparision among different property types

Sales_by_Category = data["Category"].value_counts()

# %%
Sales_by_Category
# Out:
# Category
# Office Supplies    8
# Furniture          4
# Technology         3
# Name: count, dtype: int64

# %%
# carete bar chart for above sales_by_category

# %%
Sales_by_Category.plot(kind='bar')

plt.title('Sales volume in july 2016 for different property types')
plt.ylabel('number of sales')
plt.xlabel('Category')
# Out:
# Text(0.5, 0, 'Category')
